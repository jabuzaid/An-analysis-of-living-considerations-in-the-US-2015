# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
from scipy import stats

# %%
# importing dataframes from 'project_dataclean'
city_data = pd.read_csv("Resources/Clean_Data/CityData/city_data_rent_murders_population.csv")
county_data = pd.read_csv("Resources/Clean_Data/CountyData/county_data_food_unemployment.csv")

# %%
county_data.head()
# Out:
#    Unnamed: 0     County  People 1 Mile and More  People 1/2 Mile and More  \
# 0           0  Abbeville             9451.794654               10638.20832
# 1           1     Acadia            11284.812130               17453.87802
# 2           2   Accomack            10809.972230               11984.53711
# 3           3        Ada            28009.707110               76201.38101
# 4           4      Adair             1358.349543                1541.07575
#
#    People 10 Miles and More  People 20 Miles and More  Population State  \
# 0               2422.056046                  0.000000       25417    SC
# 1                233.767029                  0.000000       61773    LA
# 2                252.378241                  0.000000       33164    VA
# 3                 48.991740                  0.532826      392365    ID
# 4                157.981000                  0.000000        7682    IA
#
#    Civilian labour force  Employed poulation  Rate of Unemployment  \
# ...

# %%
# rate of unemployment vs food scarcity 1/2 mile (county)
# plt.figure(figsize=(20, 20))
plt.scatter(county_data["Rate of Unemployment"], county_data["People 1/2 Mile and More"],
            marker="o", facecolors="red", edgecolors="black")

# Create a title, x label, and y label for our chart
plt.title("Unemployment Rate (%) vs. People \n Without Access To Food Within 1/2 Mile")
plt.ylabel("# People Without Food Access")
plt.xlabel("Unemployment Rate (%)")
plt.xticks(rotation=90)

#plt.xlim(-80, 100)
#plt.ylim(-100, 150)
plt.grid()

plt.tight_layout()

# # Save the image of the chart and print to screen
plt.savefig('Charts/unemploymentVsFoodScarcityHalfMile.png')
plt.show()

# %%
# RSQUARED for rate of unemployment vs food scarcity 1/2 mile (county)
gradient, intercept, r_value, p_value, std_err = stats.linregress(county_data["People 1/2 Mile and More"],county_data["Rate of Unemployment"])
print(f'The P-Value for unemployment rate vs food scarcity (1/2 mile) is ' + str(p_value))
# Out:
# The P-Value for unemployment rate vs food scarcity (1/2 mile) is 0.3486145860092643

# %%
# # rate of unemployment vs food scarcity 1/2 mile (county)
# # plt.figure(figsize=(20, 20))

# pop_data = [county_data["People 1/2 Mile and More"]]

# plt.scatter(pop_data, county_data["Rate of Unemployment"],
#             marker="o", facecolors="red", edgecolors="black")

# # Create a title, x label, and y label for our chart
# plt.title("Unemployment Rate (%) v. 1/2 Mile")
# plt.xlabel("# People Without Food Access")
# plt.ylabel("Unemplyment Rate (%)")
# # plt.xticks(rotation=90)

# #plt.xlim(-80, 100)
# #plt.ylim(-100, 150)
# plt.grid()

# # # Save the image of the chart and print to screen
# plt.savefig('CountyPopUnmpRate.png')
# plt.show()

# %%
# rate of unemployment vs food scarcity 1 mile (county)
# plt.figure(figsize=(20, 20))

pop_data = [county_data["People 1 Mile and More"]]

plt.scatter(county_data["Rate of Unemployment"],county_data["People 1 Mile and More"],
            marker="o", facecolors="red", edgecolors="black")

# Create a title, x label, and y label for our chart
plt.title("Unemployment Rate (%) vs. People \n Without Access To Food Within 1 Mile")
plt.ylabel("# People Without Food Access")
plt.xlabel("Unemployment Rate (%)")
# plt.xticks(rotation=90)

#plt.xlim(-80, 100)
#plt.ylim(-100, 150)
plt.grid()

plt.tight_layout()

# # Save the image of the chart and print to screen
plt.savefig('Charts/unemploymentVsFoodScarcityOneMile.png')
plt.show()

# %%
# RSQUARED for rate of unemployment vs food scarcity 1 mile (county)
gradient, intercept, r_value, p_value, std_err = stats.linregress(county_data["Rate of Unemployment"],county_data["People 1 Mile and More"])
print(f'The P-Value for unemployment rate vs food scarcity (1 mile) is ' + str(p_value))
# Out:
# The P-Value for unemployment rate vs food scarcity (1 mile) is 0.0007160918212019297

# %%
# rate of unemployment vs food scarcity 10 miles (county)
# plt.figure(figsize=(20, 20))

pop_data = [county_data["People 10 Miles and More"]]
plt.scatter(county_data["Rate of Unemployment"],county_data["People 10 Miles and More"],
            marker="o", facecolors="red", edgecolors="black")

# Create a title, x label, and y label for our chart
plt.title("Unemployment Rate (%) vs. People \n Without Access To Food Within 10 Miles")
plt.ylabel("# People Without Food Access")
plt.xlabel("Unemployment Rate (%)")
# plt.xticks(rotation=90)

#plt.xlim(-80, 100)
#plt.ylim(-100, 150)
plt.grid()

plt.tight_layout()

# # Save the image of the chart and print to screen
plt.savefig('Charts/unemploymentVsFoodScarcity10Miles.png')
plt.show()

# %%
# RSQUARED for rate of unemployment vs food scarcity 10 miles (county)
gradient, intercept, r_value, p_value, std_err = stats.linregress(county_data["Rate of Unemployment"],county_data["People 10 Miles and More"])
print(f'The P-Value for unemployment rate vs food scarcity (10 miles) is ' + str(p_value))
# Out:
# The P-Value for unemployment rate vs food scarcity (10 miles) is 1.0236545445053008e-20

# %%
# rate of unemployment vs food scarcity 20 miles (county)
# plt.figure(figsize=(20, 20))

pop_data = [county_data["People 20 Miles and More"]]
plt.scatter(county_data["Rate of Unemployment"],county_data["People 20 Miles and More"],
            marker="o", facecolors="red", edgecolors="black")

# Create a title, x label, and y label for our chart
plt.title("Unemployment Rate (%) vs. # People \n Without Access To Food Within 20 Miles")
plt.ylabel("# People Without Food Access")
plt.xlabel("Unemployment Rate (%)")
# plt.xticks(rotation=90)

#plt.xlim(-80, 100)
#plt.ylim(-100, 150)
plt.grid()

plt.tight_layout()

# # Save the image of the chart and print to screen
plt.savefig('Charts/unemploymentVsFoodScarcity20Miles.png')
plt.show()

# %%
# RSQUARED for rate of unemployment vs food scarcity 20 miles (county)
gradient, intercept, r_value, p_value, std_err = stats.linregress(county_data["Rate of Unemployment"],county_data["People 20 Miles and More"])
print(f'The P-Value for unemployment rate vs food scarcity (20 miles) is ' + str(p_value))
# Out:
# The P-Value for unemployment rate vs food scarcity (20 miles) is 2.6173327823819778e-08

# %%
# Scatter plot to showcase the relationship between County Population in USA & THE Rate of Employment in that County
# (marker="o", facecolors="red", edgecolors="black", s=scoop_price)

# plt.figure(figsize=(20, 20))
plt.scatter(county_data["Rate of Unemployment"], county_data["Population"], marker="o", facecolors="red", edgecolors="black")

# Create a title, x label, and y label for our chart
plt.title("Unemployment Rate (%) v. USA County Population")
plt.ylabel("County Population")
plt.xlabel("Unemployment Rate (%)")
plt.xticks(rotation=90)

#plt.xlim(-80, 100)
#plt.ylim(-100, 150)
plt.grid()

plt.tight_layout()

# # Save the image of the chart and print to screen
plt.savefig('Charts/CountyPopUnmpRate.png')
plt.show()

# %%
# RSQUARED for rate of unemployment vs county population
gradient, intercept, r_value, p_value, std_err = stats.linregress(county_data["Rate of Unemployment"], county_data["Population"])
print(f'The P-Value for Unemployment Rate vs County Population is ' + str(p_value))
# Out:
# The P-Value for Unemployment Rate vs County Population is 0.11300209482814276

# %%
# Scatter plot to showcase the relationship between the varias USA Cities & the average rent of that city
# (marker="o", facecolors="red", edgecolors="black", s=scoop_price)

plt.figure(figsize=(20, 20))
plt.scatter(city_data["City"], city_data["Average Rent"], marker="o", facecolors="red", edgecolors="black")

# Create a title, x label, and y label for our char plt.title("USA City v. Average Rent")
plt.xlabel("City")
plt.ylabel("Average Rent")
plt.xticks(rotation=90)

#plt.xlim(-80, 100)
#plt.ylim(-100, 150)
plt.grid()

plt.tight_layout()

# # Save the image of the chart and print to screen
plt.savefig('Charts/CityvRent.png')
plt.show()

# %%
#MURDER RATE VS RENT
# Sort the data frame by murder rate
city_data.sort_values("Murder Rate (per 100,000)")

plt.scatter(city_data["Murder Rate (per 100,000)"],city_data["Average Rent"], marker="o", facecolors="red",
            edgecolors="black")

# Create a title, x label, and y label for our chart
plt.title("Average Rent v. Murder Rate (per 100,000)")
plt.xlabel("Murder Rate (per 100,000)")
plt.ylabel("Average Rent")

plt.grid()

plt.tight_layout()

# # Save the image of the chart and print to screen
plt.savefig('Charts/MurderRateVRent.png')
# plt.show()

# %%
#MURDER RATE VS RENT W/ TRENDLINE
# Sort the data frame by murder rate
city_data.sort_values("Murder Rate (per 100,000)")

plt.scatter(city_data["Murder Rate (per 100,000)"],city_data["Average Rent"], marker="o", facecolors="red",
            edgecolors="black")

# Create a title, x label, and y label for our chart
plt.title("Average Rent v. Murder Rate (per 100,000)")
plt.xlabel("Murder Rate (per 100,000)")
plt.ylabel("Average Rent")

plt.grid()

plt.tight_layout()

#trendline
z = np.polyfit(city_data["Murder Rate (per 100,000)"], city_data["Average Rent"], 1)
p = np.poly1d(z)
plt.plot(city_data["Murder Rate (per 100,000)"],p(city_data["Murder Rate (per 100,000)"]),"r--")

 # Save the image of the chart and print to screen
plt.savefig('Charts/MurderRateVRent.png')
# plt.show()

# %%
# RSQUARED for rate of rent vs murder rate
gradient, intercept, r_value, p_value, std_err = stats.linregress(city_data["Murder Rate (per 100,000)"],city_data["Average Rent"])
print(f'The P-Value for murder rate vs average rent is ' + str(p_value))
# Out:
# The P-Value for murder rate vs average rent is 0.044042306230059294
